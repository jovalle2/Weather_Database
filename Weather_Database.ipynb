# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_long = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Latitude": city_lat,
                          "Longitude": city_long,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_data})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hualmay
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | kenitra
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | camopi
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | arsikere
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | salalah
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | clyde river
# Processing Record 22 of Set 1 | suffolk
# Processing Record 23 of Set 1 | bondo
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | padang
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | tuy hoa
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | peniche
# Processing Record 34 of Set 1 | vaitape
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | aklavik
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | krasnoselkup
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | the pas
# Processing Record 48 of Set 1 | moore
# Processing Record 49 of Set 1 | flinders
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | rabo de peixe
# Processing Record 3 of Set 2 | laguna
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | general roca
# Processing Record 6 of Set 2 | bachaquero
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | san patricio
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 13 of Set 2 | jieshi
# Processing Record 14 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 2 | weihe
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | novocherkassk
# Processing Record 18 of Set 2 | wasilla
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 21 of Set 2 | praya
# Processing Record 22 of Set 2 | del rio
# Processing Record 23 of Set 2 | vardo
# Processing Record 24 of Set 2 | falmouth
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | matara
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | emerald
# Processing Record 32 of Set 2 | saint-pierre
# Processing Record 33 of Set 2 | yatou
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | mackay
# Processing Record 37 of Set 2 | taoudenni
# Processing Record 38 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | college
# Processing Record 41 of Set 2 | mount isa
# Processing Record 42 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | neryungri
# Processing Record 45 of Set 2 | balkanabat
# Processing Record 46 of Set 2 | mayumba
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | sur
# Processing Record 49 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | viransehir
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | aitape
# Processing Record 7 of Set 3 | mecca
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | namatanai
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | dera bugti
# Processing Record 12 of Set 3 | abhayapuri
# Processing Record 13 of Set 3 | mbandaka
# Processing Record 14 of Set 3 | tunceli
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | port macquarie
# Processing Record 17 of Set 3 | rincon
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | boa vista
# Processing Record 21 of Set 3 | skegness
# Processing Record 22 of Set 3 | constantine
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | great yarmouth
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | upata
# Processing Record 27 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 3 | usinsk
# Processing Record 29 of Set 3 | codrington
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | marshalltown
# Processing Record 32 of Set 3 | hobyo
# Processing Record 33 of Set 3 | klaksvik
# Processing Record 34 of Set 3 | hurricane
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | petrivka
# Processing Record 37 of Set 3 | phrai bung
# City not found. Skipping...
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | podosinovets
# Processing Record 40 of Set 3 | maler kotla
# Processing Record 41 of Set 3 | presidencia roque saenz pena
# Processing Record 42 of Set 3 | mugur-aksy
# Processing Record 43 of Set 3 | vila velha
# Processing Record 44 of Set 3 | vytegra
# Processing Record 45 of Set 3 | cayenne
# Processing Record 46 of Set 3 | celestun
# Processing Record 47 of Set 3 | beira
# Processing Record 48 of Set 3 | road town
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | praia da vitoria
# Processing Record 1 of Set 4 | paramonga
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | mitsamiouli
# Processing Record 4 of Set 4 | pingliang
# Processing Record 5 of Set 4 | san policarpo
# Processing Record 6 of Set 4 | coquimbo
# Processing Record 7 of Set 4 | cape town
# Processing Record 8 of Set 4 | alausi
# Processing Record 9 of Set 4 | ternovka
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | santiago de cuba
# Processing Record 14 of Set 4 | grand gaube
# Processing Record 15 of Set 4 | nantucket
# Processing Record 16 of Set 4 | vanimo
# Processing Record 17 of Set 4 | faya
# Processing Record 18 of Set 4 | dukat
# Processing Record 19 of Set 4 | dhangadhi
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | asyut
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | wloszczowa
# Processing Record 25 of Set 4 | shenzhen
# Processing Record 26 of Set 4 | palm coast
# Processing Record 27 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 4 | leningradskiy
# Processing Record 29 of Set 4 | acarau
# Processing Record 30 of Set 4 | bindki
# Processing Record 31 of Set 4 | harper
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | tazovskiy
# Processing Record 34 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 4 | gat
# Processing Record 36 of Set 4 | hammerfest
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | masyaf
# Processing Record 41 of Set 4 | bereda
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | half moon bay
# Processing Record 44 of Set 4 | iralaya
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | honiara
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | kyshtovka
# Processing Record 49 of Set 4 | jiazi
# Processing Record 50 of Set 4 | karpathos
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | asau
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | coos bay
# Processing Record 5 of Set 5 | nanakuli
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | wanning
# Processing Record 9 of Set 5 | kunya
# Processing Record 10 of Set 5 | mountain home
# Processing Record 11 of Set 5 | saint-philippe
# Processing Record 12 of Set 5 | burnie
# Processing Record 13 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | beyla
# Processing Record 16 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 5 | allanmyo
# City not found. Skipping...
# Processing Record 18 of Set 5 | avera
# Processing Record 19 of Set 5 | kidal
# Processing Record 20 of Set 5 | xining
# Processing Record 21 of Set 5 | joshimath
# Processing Record 22 of Set 5 | kulunda
# Processing Record 23 of Set 5 | christchurch
# Processing Record 24 of Set 5 | atar
# Processing Record 25 of Set 5 | nkhotakota
# Processing Record 26 of Set 5 | mindelo
# Processing Record 27 of Set 5 | tutoia
# Processing Record 28 of Set 5 | guasdualito
# Processing Record 29 of Set 5 | miri
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | el banco
# Processing Record 34 of Set 5 | ko samui
# Processing Record 35 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 5 | moose factory
# Processing Record 37 of Set 5 | kangaba
# Processing Record 38 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 5 | hailey
# Processing Record 41 of Set 5 | nur
# Processing Record 42 of Set 5 | lincoln
# Processing Record 43 of Set 5 | broken hill
# Processing Record 44 of Set 5 | tomatlan
# Processing Record 45 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 46 of Set 5 | omboue
# Processing Record 47 of Set 5 | zhuanghe
# Processing Record 48 of Set 5 | kamaishi
# Processing Record 49 of Set 5 | port augusta
# Processing Record 50 of Set 5 | havre-saint-pierre
# Processing Record 1 of Set 6 | saldanha
# Processing Record 2 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 6 | bonavista
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | tarko-sale
# Processing Record 6 of Set 6 | callaway
# Processing Record 7 of Set 6 | kawalu
# Processing Record 8 of Set 6 | pishchanka
# City not found. Skipping...
# Processing Record 9 of Set 6 | panjwin
# City not found. Skipping...
# Processing Record 10 of Set 6 | vypolzovo
# Processing Record 11 of Set 6 | preobrazheniye
# Processing Record 12 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 6 | severomuysk
# Processing Record 14 of Set 6 | mehamn
# Processing Record 15 of Set 6 | lompoc
# Processing Record 16 of Set 6 | mamakan
# Processing Record 17 of Set 6 | olinda
# Processing Record 18 of Set 6 | nouakchott
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | nelson
# Processing Record 21 of Set 6 | nador
# Processing Record 22 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 6 | bay roberts
# Processing Record 24 of Set 6 | paysandu
# Processing Record 25 of Set 6 | adra
# Processing Record 26 of Set 6 | ozernovskiy
# Processing Record 27 of Set 6 | puerto escondido
# Processing Record 28 of Set 6 | terrace bay
# Processing Record 29 of Set 6 | aswan
# Processing Record 30 of Set 6 | manzhouli
# Processing Record 31 of Set 6 | los llanos de aridane
# Processing Record 32 of Set 6 | east moline
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 6 | fonte boa
# Processing Record 36 of Set 6 | immokalee
# Processing Record 37 of Set 6 | bethel
# Processing Record 38 of Set 6 | loikaw
# Processing Record 39 of Set 6 | coari
# Processing Record 40 of Set 6 | kot samaba
# Processing Record 41 of Set 6 | rocha
# Processing Record 42 of Set 6 | mezen
# Processing Record 43 of Set 6 | charters towers
# Processing Record 44 of Set 6 | murupara
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 6 | shitanjing
# Processing Record 48 of Set 6 | lovozero
# Processing Record 49 of Set 6 | unye
# City not found. Skipping...
# Processing Record 50 of Set 6 | iquitos
# Processing Record 1 of Set 7 | khandbari
# Processing Record 2 of Set 7 | aquiraz
# Processing Record 3 of Set 7 | mogadouro
# Processing Record 4 of Set 7 | nola
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | kruisfontein
# Processing Record 7 of Set 7 | bilibino
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | chumikan
# Processing Record 10 of Set 7 | kargasok
# Processing Record 11 of Set 7 | saint-joseph
# Processing Record 12 of Set 7 | smithers
# Processing Record 13 of Set 7 | zarubino
# Processing Record 14 of Set 7 | suleja
# Processing Record 15 of Set 7 | villa carlos paz
# Processing Record 16 of Set 7 | calvinia
# Processing Record 17 of Set 7 | goteborg
# City not found. Skipping...
# Processing Record 18 of Set 7 | isangel
# Processing Record 19 of Set 7 | ponta delgada
# Processing Record 20 of Set 7 | stilling
# Processing Record 21 of Set 7 | dunedin
# Processing Record 22 of Set 7 | pimentel
# Processing Record 23 of Set 7 | poum
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | clonakilty
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | qandala
# Processing Record 28 of Set 7 | ambulu
# Processing Record 29 of Set 7 | luau
# Processing Record 30 of Set 7 | portland
# Processing Record 31 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 7 | hervey bay
# Processing Record 33 of Set 7 | constitucion
# Processing Record 34 of Set 7 | cherskiy
# Processing Record 35 of Set 7 | mumford
# Processing Record 36 of Set 7 | necochea
# Processing Record 37 of Set 7 | barcelos
# Processing Record 38 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 41 of Set 7 | synya
# Processing Record 42 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 7 | metro
# Processing Record 44 of Set 7 | baruun-urt
# Processing Record 45 of Set 7 | tarrafal
# Processing Record 46 of Set 7 | haines junction
# Processing Record 47 of Set 7 | vyartsilya
# Processing Record 48 of Set 7 | maunabo
# Processing Record 49 of Set 7 | samarai
# Processing Record 50 of Set 7 | stephenville
# Processing Record 1 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 8 | soc trang
# Processing Record 3 of Set 8 | lagunas
# Processing Record 4 of Set 8 | weihai
# Processing Record 5 of Set 8 | atka
# City not found. Skipping...
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | srednekolymsk
# Processing Record 8 of Set 8 | beaupre
# Processing Record 9 of Set 8 | tabat
# Processing Record 10 of Set 8 | itagiba
# Processing Record 11 of Set 8 | nieuw amsterdam
# Processing Record 12 of Set 8 | sisimiut
# Processing Record 13 of Set 8 | fallon
# Processing Record 14 of Set 8 | sarangani
# Processing Record 15 of Set 8 | belyy yar
# Processing Record 16 of Set 8 | bilma
# Processing Record 17 of Set 8 | bocanda
# Processing Record 18 of Set 8 | japura
# Processing Record 19 of Set 8 | along
# Processing Record 20 of Set 8 | kaberamaido
# Processing Record 21 of Set 8 | dalen
# Processing Record 22 of Set 8 | chopovychi
# Processing Record 23 of Set 8 | sitka
# Processing Record 24 of Set 8 | zaysan
# Processing Record 25 of Set 8 | arlit
# Processing Record 26 of Set 8 | tigil
# Processing Record 27 of Set 8 | farafangana
# Processing Record 28 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 8 | nalut
# Processing Record 30 of Set 8 | shache
# Processing Record 31 of Set 8 | kiruna
# Processing Record 32 of Set 8 | cam ranh
# Processing Record 33 of Set 8 | vattalkundu
# Processing Record 34 of Set 8 | severo-kurilsk
# Processing Record 35 of Set 8 | cabo san lucas
# Processing Record 36 of Set 8 | evensk
# Processing Record 37 of Set 8 | riyadh
# Processing Record 38 of Set 8 | shakawe
# Processing Record 39 of Set 8 | ostrovnoy
# Processing Record 40 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 8 | morro bay
# Processing Record 42 of Set 8 | vetrisoaia
# Processing Record 43 of Set 8 | najran
# Processing Record 44 of Set 8 | aban
# Processing Record 45 of Set 8 | nemuro
# Processing Record 46 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 8 | coihaique
# Processing Record 48 of Set 8 | riberalta
# Processing Record 49 of Set 8 | vila franca do campo
# Processing Record 50 of Set 8 | papagaios
# Processing Record 1 of Set 9 | moranbah
# Processing Record 2 of Set 9 | sao filipe
# Processing Record 3 of Set 9 | vao
# Processing Record 4 of Set 9 | yaring
# Processing Record 5 of Set 9 | pachino
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | tahe
# Processing Record 8 of Set 9 | chambar
# Processing Record 9 of Set 9 | batagay-alyta
# Processing Record 10 of Set 9 | markdale
# Processing Record 11 of Set 9 | ardahan
# Processing Record 12 of Set 9 | alyangula
# Processing Record 13 of Set 9 | adrar
# Processing Record 14 of Set 9 | atambua
# Processing Record 15 of Set 9 | svetlogorsk
# Processing Record 16 of Set 9 | prado
# Processing Record 17 of Set 9 | waitati
# Processing Record 18 of Set 9 | berlevag
# Processing Record 19 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 9 | muisne
# Processing Record 21 of Set 9 | carutapera
# Processing Record 22 of Set 9 | la palma
# Processing Record 23 of Set 9 | sovetskiy
# Processing Record 24 of Set 9 | okhotsk
# Processing Record 25 of Set 9 | kaeo
# Processing Record 26 of Set 9 | pisco
# Processing Record 27 of Set 9 | kalmunai
# Processing Record 28 of Set 9 | tulu bolo
# Processing Record 29 of Set 9 | vetlanda
# Processing Record 30 of Set 9 | henties bay
# Processing Record 31 of Set 9 | ranong
# Processing Record 32 of Set 9 | lasa
# Processing Record 33 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 9 | quelimane
# Processing Record 36 of Set 9 | margate
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | creel
# Processing Record 39 of Set 9 | richards bay
# Processing Record 40 of Set 9 | arawa
# Processing Record 41 of Set 9 | nairn
# Processing Record 42 of Set 9 | puerto del rosario
# Processing Record 43 of Set 9 | kilimatinde
# Processing Record 44 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 9 | sile
# Processing Record 46 of Set 9 | shellbrook
# Processing Record 47 of Set 9 | seybaplaya
# Processing Record 48 of Set 9 | miandrivazo
# Processing Record 49 of Set 9 | luz
# Processing Record 50 of Set 9 | ambilobe
# Processing Record 1 of Set 10 | ketchikan
# Processing Record 2 of Set 10 | sibolga
# Processing Record 3 of Set 10 | mandalgovi
# Processing Record 4 of Set 10 | odweyne
# Processing Record 5 of Set 10 | goderich
# Processing Record 6 of Set 10 | menongue
# Processing Record 7 of Set 10 | mgandu
# Processing Record 8 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 10 | gadwal
# Processing Record 10 of Set 10 | jacupiranga
# Processing Record 11 of Set 10 | ampanihy
# Processing Record 12 of Set 10 | chase
# Processing Record 13 of Set 10 | faanui
# Processing Record 14 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 10 | karaton
# Processing Record 16 of Set 10 | macara
# Processing Record 17 of Set 10 | marsh harbour
# Processing Record 18 of Set 10 | saraland
# Processing Record 19 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 20 of Set 10 | walvis bay
# Processing Record 21 of Set 10 | new bern
# Processing Record 22 of Set 10 | khorixas
# Processing Record 23 of Set 10 | dawlatabad
# Processing Record 24 of Set 10 | hohhot
# Processing Record 25 of Set 10 | edd
# Processing Record 26 of Set 10 | tairua
# Processing Record 27 of Set 10 | hovd
# Processing Record 28 of Set 10 | idanre
# Processing Record 29 of Set 10 | marawi
# Processing Record 30 of Set 10 | khromtau
# Processing Record 31 of Set 10 | jertih
# Processing Record 32 of Set 10 | ducheng
# Processing Record 33 of Set 10 | kwinana
# Processing Record 34 of Set 10 | rio grande
# Processing Record 35 of Set 10 | ahipara
# Processing Record 36 of Set 10 | pangai
# Processing Record 37 of Set 10 | kandrian
# Processing Record 38 of Set 10 | ha tinh
# Processing Record 39 of Set 10 | grottammare
# Processing Record 40 of Set 10 | bosaso
# Processing Record 41 of Set 10 | oranjemund
# Processing Record 42 of Set 10 | lashio
# Processing Record 43 of Set 10 | bulgan
# Processing Record 44 of Set 10 | meulaboh
# Processing Record 45 of Set 10 | yangshe
# Processing Record 46 of Set 10 | songling
# Processing Record 47 of Set 10 | biloela
# Processing Record 48 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 10 | kharitonovo
# Processing Record 50 of Set 10 | okakarara
# Processing Record 1 of Set 11 | acapulco
# Processing Record 2 of Set 11 | pacific grove
# Processing Record 3 of Set 11 | gallup
# Processing Record 4 of Set 11 | la ronge
# Processing Record 5 of Set 11 | kaspiyskiy
# Processing Record 6 of Set 11 | geraldton
# Processing Record 7 of Set 11 | santander
# Processing Record 8 of Set 11 | alice springs
# Processing Record 9 of Set 11 | marsaxlokk
# Processing Record 10 of Set 11 | yeppoon
# Processing Record 11 of Set 11 | kendari
# Processing Record 12 of Set 11 | hambantota
# Processing Record 13 of Set 11 | udachnyy
# Processing Record 14 of Set 11 | lavrentiya
# Processing Record 15 of Set 11 | tecoanapa
# Processing Record 16 of Set 11 | gamba
# Processing Record 17 of Set 11 | porto novo
# Processing Record 18 of Set 11 | chifeng
# Processing Record 19 of Set 11 | gofitskoye
# Processing Record 20 of Set 11 | caravelas
# Processing Record 21 of Set 11 | aloleng
# Processing Record 22 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 11 | fortuna
# Processing Record 24 of Set 11 | fort dodge
# Processing Record 25 of Set 11 | belle glade
# Processing Record 26 of Set 11 | aripuana
# Processing Record 27 of Set 11 | ucluelet
# Processing Record 28 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 11 | toora-khem
# Processing Record 30 of Set 11 | umea
# Processing Record 31 of Set 11 | sinnamary
# Processing Record 32 of Set 11 | batsfjord
# Processing Record 33 of Set 11 | stromness
# Processing Record 34 of Set 11 | isiro
# Processing Record 35 of Set 11 | beachwood
# Processing Record 36 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 11 | wynyard
# Processing Record 38 of Set 11 | kocsord
# Processing Record 39 of Set 11 | asfi
# Processing Record 40 of Set 11 | gizo
# Processing Record 41 of Set 11 | saqqez
# Processing Record 42 of Set 11 | fereydun kenar
# Processing Record 43 of Set 11 | merauke
# Processing Record 44 of Set 11 | dalvik
# Processing Record 45 of Set 11 | narsaq
# Processing Record 46 of Set 11 | noumea
# Processing Record 47 of Set 11 | saint-augustin
# Processing Record 48 of Set 11 | kamachumu
# Processing Record 49 of Set 11 | ciudad bolivar
# Processing Record 50 of Set 11 | lapeer
# Processing Record 1 of Set 12 | tongren
# Processing Record 2 of Set 12 | kang
# Processing Record 3 of Set 12 | taltal
# Processing Record 4 of Set 12 | buala
# Processing Record 5 of Set 12 | high level
# Processing Record 6 of Set 12 | colares
# Processing Record 7 of Set 12 | san carlos de bariloche
# Processing Record 8 of Set 12 | palauig
# Processing Record 9 of Set 12 | new glasgow
# Processing Record 10 of Set 12 | nauchnyy gorodok
# Processing Record 11 of Set 12 | beyneu
# Processing Record 12 of Set 12 | vestmannaeyjar
# Processing Record 13 of Set 12 | ulladulla
# Processing Record 14 of Set 12 | oistins
# Processing Record 15 of Set 12 | wajir
# Processing Record 16 of Set 12 | santa cruz cabralia
# Processing Record 17 of Set 12 | te anau
# Processing Record 18 of Set 12 | antsohihy
# Processing Record 19 of Set 12 | siniscola
# Processing Record 20 of Set 12 | bambanglipuro
# Processing Record 21 of Set 12 | avrille
# Processing Record 22 of Set 12 | seaside
# Processing Record 23 of Set 12 | santiago del estero
# Processing Record 24 of Set 12 | langres
# Processing Record 25 of Set 12 | luderitz
# Processing Record 26 of Set 12 | taber
# Processing Record 27 of Set 12 | baykit
# Processing Record 28 of Set 12 | amapa
# Processing Record 29 of Set 12 | balikpapan
# Processing Record 30 of Set 12 | aksarka
# Processing Record 31 of Set 12 | maua
# Processing Record 32 of Set 12 | darnah
# Processing Record 33 of Set 12 | sokoni
# Processing Record 34 of Set 12 | mnogovershinnyy
# Processing Record 35 of Set 12 | butka
# Processing Record 36 of Set 12 | karratha
# Processing Record 37 of Set 12 | itarema
# Processing Record 38 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 12 | santa helena
# Processing Record 40 of Set 12 | trincomalee
# Processing Record 41 of Set 12 | kavieng
# Processing Record 42 of Set 12 | inongo
# Processing Record 43 of Set 12 | korla
# Processing Record 44 of Set 12 | gazli
# Processing Record 45 of Set 12 | selcuk
# Processing Record 46 of Set 12 | nysa
# Processing Record 47 of Set 12 | mangaluru
# Processing Record 48 of Set 12 | jyvaskyla
# Processing Record 49 of Set 12 | toguchin
# Processing Record 50 of Set 12 | merke
# Processing Record 1 of Set 13 | kabwe
# Processing Record 2 of Set 13 | hay river
# Processing Record 3 of Set 13 | seoul
# Processing Record 4 of Set 13 | dera ghazi khan
# Processing Record 5 of Set 13 | jiuquan
# Processing Record 6 of Set 13 | buchanan
# Processing Record 7 of Set 13 | conakry
# Processing Record 8 of Set 13 | bow island
# Processing Record 9 of Set 13 | beisfjord
# Processing Record 10 of Set 13 | barentu
# Processing Record 11 of Set 13 | laurel
# Processing Record 12 of Set 13 | wadi musa
# Processing Record 13 of Set 13 | palapye
# Processing Record 14 of Set 13 | nabire
# Processing Record 15 of Set 13 | jibuti
# Processing Record 16 of Set 13 | placerville
# Processing Record 17 of Set 13 | jaque
# Processing Record 18 of Set 13 | kommunisticheskiy
# Processing Record 19 of Set 13 | toamasina
# Processing Record 20 of Set 13 | rawson
# Processing Record 21 of Set 13 | ahuimanu
# Processing Record 22 of Set 13 | manyoni
# Processing Record 23 of Set 13 | rimavska sobota
# Processing Record 24 of Set 13 | tibagi
# Processing Record 25 of Set 13 | ternate
# Processing Record 26 of Set 13 | sept-iles
# Processing Record 27 of Set 13 | komsomolskiy
# Processing Record 28 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 13 | chibuto
# Processing Record 30 of Set 13 | roxana
# Processing Record 31 of Set 13 | sarahan
# Processing Record 32 of Set 13 | zambezi
# Processing Record 33 of Set 13 | lagos
# Processing Record 34 of Set 13 | west wendover
# Processing Record 35 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 13 | sokol
# Processing Record 37 of Set 13 | hvolsvollur
# Processing Record 38 of Set 13 | price
# Processing Record 39 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 13 | itoman
# Processing Record 41 of Set 13 | aksu
# Processing Record 42 of Set 13 | vaovai
# City not found. Skipping...
# Processing Record 43 of Set 13 | paamiut
# Processing Record 44 of Set 13 | sinegorye
# Processing Record 45 of Set 13 | hamilton
# Processing Record 46 of Set 13 | mago
# Processing Record 47 of Set 13 | yulara
# Processing Record 48 of Set 13 | tarabuco
# Processing Record 49 of Set 13 | terenos
# Processing Record 50 of Set 13 | plastun
# Processing Record 1 of Set 14 | sao joao da barra
# Processing Record 2 of Set 14 | bathsheba
# Processing Record 3 of Set 14 | belaya kholunitsa
# Processing Record 4 of Set 14 | altay
# Processing Record 5 of Set 14 | sola
# Processing Record 6 of Set 14 | wahiawa
# Processing Record 7 of Set 14 | bolgatanga
# Processing Record 8 of Set 14 | khani
# Processing Record 9 of Set 14 | selikhino
# Processing Record 10 of Set 14 | nouadhibou
# Processing Record 11 of Set 14 | nizhniy odes
# Processing Record 12 of Set 14 | opuwo
# Processing Record 13 of Set 14 | naberera
# Processing Record 14 of Set 14 | talaya
# Processing Record 15 of Set 14 | surgut
# Processing Record 16 of Set 14 | shush
# Processing Record 17 of Set 14 | bucerias
# Processing Record 18 of Set 14 | shakiso
# Processing Record 19 of Set 14 | chala
# Processing Record 20 of Set 14 | ponorogo
# Processing Record 21 of Set 14 | bam
# Processing Record 22 of Set 14 | pilar
# Processing Record 23 of Set 14 | chapais
# Processing Record 24 of Set 14 | morgan city
# Processing Record 25 of Set 14 | mossendjo
# Processing Record 26 of Set 14 | aden
# Processing Record 27 of Set 14 | shieli
# Processing Record 28 of Set 14 | sao miguel do araguaia
# Processing Record 29 of Set 14 | pozoblanco
# Processing Record 30 of Set 14 | kaka
# Processing Record 31 of Set 14 | zabaykalsk
# Processing Record 32 of Set 14 | zhanakorgan
# Processing Record 33 of Set 14 | filingue
# Processing Record 34 of Set 14 | marzuq
# Processing Record 35 of Set 14 | kavaratti
# Processing Record 36 of Set 14 | arlington
# Processing Record 37 of Set 14 | bairiki
# Processing Record 38 of Set 14 | valkeala
# Processing Record 39 of Set 14 | nurota
# Processing Record 40 of Set 14 | loveland
# Processing Record 41 of Set 14 | mosjoen
# Processing Record 42 of Set 14 | talnakh
# Processing Record 43 of Set 14 | lao cai
# Processing Record 44 of Set 14 | damavand
# Processing Record 45 of Set 14 | colquechaca
# Processing Record 46 of Set 14 | fujin
# Processing Record 47 of Set 14 | yar-sale
# Processing Record 48 of Set 14 | sangueya
# Processing Record 49 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 14 | dutlwe
# Processing Record 1 of Set 15 | guata
# City not found. Skipping...
# Processing Record 2 of Set 15 | teknaf
# Processing Record 3 of Set 15 | tiznit
# Processing Record 4 of Set 15 | amuntai
# Processing Record 5 of Set 15 | el alto
# Processing Record 6 of Set 15 | santa catarina de tepehuanes
# Processing Record 7 of Set 15 | yola
# Processing Record 8 of Set 15 | sandwick
# Processing Record 9 of Set 15 | pathein
# Processing Record 10 of Set 15 | dalbandin
# Processing Record 11 of Set 15 | smoky lake
# Processing Record 12 of Set 15 | kindu
# Processing Record 13 of Set 15 | qaqortoq
# Processing Record 14 of Set 15 | cuddapah
# Processing Record 15 of Set 15 | sechura
# Processing Record 16 of Set 15 | banamba
# Processing Record 17 of Set 15 | dalby
# Processing Record 18 of Set 15 | olafsvik
# Processing Record 19 of Set 15 | bianzhuang
# Processing Record 20 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 15 | la rioja
# Processing Record 22 of Set 15 | saint anthony
# Processing Record 23 of Set 15 | alzamay
# Processing Record 24 of Set 15 | jackson
# Processing Record 25 of Set 15 | fairbanks
# Processing Record 26 of Set 15 | honningsvag
# Processing Record 27 of Set 15 | abu samrah
# Processing Record 28 of Set 15 | nadrag
# Processing Record 29 of Set 15 | cayhagan
# Processing Record 30 of Set 15 | novyy urengoy
# Processing Record 31 of Set 15 | maragogi
# Processing Record 32 of Set 15 | banff
# Processing Record 33 of Set 15 | mizoch
# Processing Record 34 of Set 15 | fethiye
# Processing Record 35 of Set 15 | wewak
# Processing Record 36 of Set 15 | santo antonio de padua
# Processing Record 37 of Set 15 | zemio
# Processing Record 38 of Set 15 | monrovia
# Processing Record 39 of Set 15 | oum hadjer
# Processing Record 40 of Set 15 | panjab
# Processing Record 41 of Set 15 | poyarkovo
# Processing Record 42 of Set 15 | hami
# Processing Record 43 of Set 15 | cururupu
# Processing Record 44 of Set 15 | rolla
# Processing Record 45 of Set 15 | iranshahr
# Processing Record 46 of Set 15 | bundaberg
# Processing Record 47 of Set 15 | dzhebariki-khaya
# Processing Record 48 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 15 | valdivia
# Processing Record 50 of Set 15 | micheweni
# Processing Record 1 of Set 16 | vostok
# Processing Record 2 of Set 16 | oktyabrskiy
# Processing Record 3 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 16 | saint-denis
# Processing Record 5 of Set 16 | idrinskoye
# Processing Record 6 of Set 16 | mahibadhoo
# Processing Record 7 of Set 16 | porechye-rybnoye
# Processing Record 8 of Set 16 | ranfurly
# Processing Record 9 of Set 16 | lagoa
# Processing Record 10 of Set 16 | bismil
# Processing Record 11 of Set 16 | pochutla
# Processing Record 12 of Set 16 | ulaanbaatar
# Processing Record 13 of Set 16 | quatre cocos
# Processing Record 14 of Set 16 | jumla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Latitude', 'Longitude', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Latitude","Longitude", "Max Temp", "Humidity", "Cloudiness", "Wind", "Current Description", "Date"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Latitude               float64
# Longitude              float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind                   float64
# Current Description     object
# Date                    object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather-Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
